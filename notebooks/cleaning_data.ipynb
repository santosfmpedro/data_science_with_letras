# %%
import pandas as pd
import re
# importing sys
import sys
 
# adding Folder_2 to the system path
sys.path.insert(0, 'E:\coding\github\data_science_with_letras\src')

import clean_data as cd

local_lyrics = "E:/coding/github/webscraping_letras/data/raw/lyrics"

# %%
def clean_lyrics(local_lyrics, local_salvar):
    all_lyrics = cd.read_any(local_lyrics)
    df = pd.DataFrame({'song': [],
                   'artist': [],
                   'views': [],
                   'n_verses': [],
                   'n_rows': [],
                   'lyric': [],
                   'clean_lyric': []})

    for lyric in all_lyrics[:1000]:

        try:
            lyric_df = pd.read_table(lyric, 
                        header=None)
        except:
            print("Error reading the file!")
        
        df_aux = pd.DataFrame({'song': [lyric_df[0][0].replace('Song:', '')],
                    'genre': [lyric.split('\\')[-1].split('___')[0]],
                    'directory': [lyric],
                    'artist': [lyric_df[0][1].replace('Artist:', '')],
                    'views': [lyric_df[0][2].replace('Views:', '')],
                    'n_verses': [lyric_df[0][3].replace('Verses:', '')],
                    'n_rows': [len(lyric_df[0][4].split('''','''))],
                    'lyric': [lyric_df[0][4]],
                    'clean_lyric': [cd.clean_lyric(lyric_df[0][4])]})
        
        df = pd.concat([df, df_aux])

    df = df.reset_index()
    df.to_csv('silver_data_lyrics.csv',index=False)

# %%
df = pd.DataFrame({'song': [],
                   'artist': [],
                   'views': [],
                   'n_verses': [],
                   'n_rows': [],
                   'lyric': [],
                   'clean_lyric': []})

for lyric in all_lyrics:

    try:
        lyric_df = pd.read_table(lyric, 
                      header=None)
    except:
        print("Error reading the file!")
    
    df_aux = pd.DataFrame({'song': [lyric_df[0][0].replace('Song:', '')],
                   'artist': [lyric_df[0][1].replace('Artist:', '')],
                   'views': [lyric_df[0][2].replace('Views:', '')],
                   'n_verses': [lyric_df[0][3].replace('Verses:', '')],
                   'n_rows': [len(lyric_df[0][4].split('''','''))],
                   'lyric': [lyric_df[0][4]],
                   'clean_lyric': [cd.clean_lyric(lyric_df[0][4])]})
    
    df = pd.concat([df, df_aux])

df = df.reset_index()

# %%
for lyric in all_lyrics[:20]:
    print(lyric)
# Out:
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1105878_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1528405_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1528406_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1608254_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1624557_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1624558_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1624559_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1624560_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1624561_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1624562_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1624563_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1624564_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1800003_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1800004_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1800005_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1800006_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1987815_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_1987816_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_dai-zero-kan_.txt
# E:/coding/github/webscraping_letras/data/raw/lyrics\alternativo___10-feet____10-feet_hammer-ska_.txt

# %%
data = df.head(1000)

# %%
data
# Out:
#      index                                 song       artist  views n_verses  \
# 0        0                     Stone Cold Break      10-FEET    645        5
# 1        0   Little More Than Before (slip Out)      10-FEET    763        5
# 2        0                Islands In The Stream      10-FEET    245        4
# 3        0                                River      10-FEET    345        7
# 4        0                                Shoes      10-FEET    163        8
# ..     ...                                  ...          ...    ...      ...
# 995      0                           Ghost Town   Ariel Pink     18        7
# 996      0                               Ghosts   Ariel Pink     17       18
# 997      0                       Girl In a Tree   Ariel Pink     98       13
# 998      0             Good Kids Make Bad Grown   Ariel Pink     87       12
# 999      0                          Gopacapuclo   Ariel Pink     15        6
#
#      n_rows                                              lyric  \
# 0      19.0  ["So always let it be more light. now you're i...
# 1      14.0  ["I don't know since when I changed to such a ...
# 2      52.0  ['Baby when i met you there', 'Was peace unkno...
# 3      41.0  ["It's just a waste of time if you can't do an...
# 4      22.0  ['I came across that scenery, it brought back ...
# ..      ...                                                ...
# 995    26.0  ['Unh!', 'Ghost town.', 'Hey!', "Get in. i'll ...
# 996    50.0  ['Go away, ghosts,', 'Go far away', "I don't w...
# 997    57.0  ['This song is dedicated', 'To the girl that i...
# 998    41.0  ['They say that part of growing up is', 'Getti...
# 999    26.0  ["Why don't you go out with my girl?", "Wouldn...
#
#                                            clean_lyric
# 0    so always let it be more light now youre in th...
# 1    i dont know since when i changed to such a col...
# 2    baby when i met you there was peace unknown i ...
# 3    its just a waste of time if you cant do anymor...
# 4    i came across that scenery it brought back tho...
# ..                                                 ...
# 995  unh ghost town hey get in ill take you for a r...
# 996  go away ghosts go far away i dont want you in ...
# 997  this song is dedicated to the girl that i love...
# 998  they say that part of growing up is getting a ...
# 999  why dont you go out with my girl wouldnt you  ...
#
# [1000 rows x 8 columns]
